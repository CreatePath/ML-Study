# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
cd drive/MyDrive/Colab Notebooks/ML-Study/ML-Study/DeepLearning/DeepLearning_from_Scratch
# Out:
# /content/drive/MyDrive/Colab Notebooks/ML-Study/ML-Study/DeepLearning/DeepLearning_from_Scratch

# %%
import numpy as np
import sys, os
sys.path.append(os.pardir)
from dataset.mnist import load_mnist

# %%
(x_train, t_train), (x_test, t_train) = load_mnist(normalize=True, one_hot_label=True)

print(x_train.shape)
print(t_train.shape)
# Out:
# (60000, 784)
# (10000, 10)

# %%
train_size = x_train.shape[0]
batch_size = 10
batch_mask = np.random.coice(train_size, batch_size)
x_batch = x_train[batch_mask]
y_batch = t_train[batch_mask]
